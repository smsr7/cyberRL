# %%
import pandas as pd
import numpy as np

# %%
path = "model_saves/ladder_20240611_172229"
data = pd.read_csv(f'{path}/out_eval.csv')
data.head()
# Out:
#    step  episode  mean_length  std_length  mean_attacker_reward  \
# 0     0        0       2000.0         0.0                   4.2
# 1     1        0       2000.0         0.0                   3.6
# 2     2        0       2000.0         0.0                   1.2
# 3     3        0       2000.0         0.0                   3.6
# 4     4        0       2000.0         0.0                   2.4
#
#    std_attacker_reward  mean_attacker_valid  std_attacker_valid  \
# 0             5.878775                225.2            5.035871
# 1             2.939388                227.2            6.794115
# 2             2.400000                232.6           14.192956
# 3             2.939388                213.4           10.575443
# 4             2.939388                233.0           10.714476
#
#    mean_attacker_invalid  std_attacker_invalid  mean_defender_reward  \
# 0                 1774.8              5.035871             -198110.8
# ...
